# %%
# Задание task_01_01.
# Выполнил: Соболева Д.Ю.
# Группа: ЦИБ - 251


a = int(input("a="))
b = int(input("b="))

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)

print(a < b)
print(a <= b)
print(a > b)
print(a >= b)
print(a != b)
print(a == b)
# Out:
# a=3
# b=6
# 9
# -3
# 18
# 0.5
# 0
# 3
# 729
# True
# True
# False
# False
# True
# False
